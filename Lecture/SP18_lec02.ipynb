# %% [markdown]
# ## Arithmetic

# %%
#tip: cell -> run all 
#tip: use this when you leave and come back to assignment (have to run the first cell again)
#tip: use this before you submit an assignment to make sure your code does what you think it does


from IPython.display import Image
Image("ar_op.png")

# %%
# Out:
# 5

# %%
# Out:
# 6

# %%
# Out:
# 8

# %%
2 / 3
# Out:
# 0.6666666666666666

# %%
2 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-ae0c5d243292> in <module>()
# ----> 1 2 / 0
#
# ZeroDivisionError: division by zero

# %%
1 + 2 * 3 * 4 * 5 / 6 ** 2 + 7 + 8 - 9 + 10
# Out:
# 20.333333333333336

# %%
1 + 2 * (3 * 4 * 5 / 6 ** 2 + 7 + 8 - 9 + 10
# Out:
#   File "<ipython-input-7-b4ce15533dab>", line 1
#     1 + 2 * (3 * 4 * 5 / 6 ** 2 + 7 + 8 - 9 + 10
#                                                 ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## Numbers

# %%
2
# Out:
# 2

# %%
2.0
# Out:
# 2.0

# %%
2 / 1
# Out:
# 2.0

# %%
1 + 1
# Out:
# 2

# %%
5 / 7000
# Out:
# 0.0007142857142857143

# %%
# scientific notation
5 / 70000
# Out:
# 7.142857142857143e-05

# %%
0.0000000000000000123456789
# Out:
# 1.23456789e-17

# %%
0.000000000000000123456789 ** 30
# Out:
# 0.0

# %%
...
# Out:
# ...

# %%
....2
# Out:
# inf

# %%
0.666666666666666666123456789
# Out:
# 0.6666666666666666

# %%
0.6666666666666666 - 0.6666666666666666123456789
# Out:
# 0.0

# %%
# square root

2 ** 0.5
# Out:
# 1.4142135623730951

# %%
# what do you expect

(2 ** 0.5) * (2 ** 0.5)
# Out:
# 2.0000000000000004

# %%
(2 ** 0.5) * (2 ** 0.5) - 2
# Out:
# 4.440892098500626e-16

# %%
from IPython.display import Image
Image("intsfloats.png")

# %% [markdown]
# ### Discussion Question

# %%
from IPython.display import Image
Image("q1.png")

# %%
3 * 10 ** 10

# %%
10 * 3 ** 10

# %%
(10 * 3) ** 10

# %%
10 / 3 / 10

# %%
10 / (3 / 10)

# %%
#(back to slides)

# %% [markdown]
# ## Names (Variables)

# %%
more_than_1 = 2 + 3

# %%
more_than_1
# Out:
# 5

# %%
more_than_1 * 2
# Out:
# 10

# %%
# what will be printed?
more_than_1
# Out:
# 5

# %%
more_than_1 = more_than_1*2
more_than_1

#run this cell a few times
# Out:
# 10

# %%
more_than_1
7+7
# Out:
# 14

# %%
x = 4
y = x + 1
y
# Out:
# 5

# %%
x = 3
x
# Out:
# 3

# %%
#what is y?
y
# Out:
# 5

# %% [markdown]
# ## Call Expressions

# %%
from IPython.display import Image
Image("call.png")

# %%
abs(-12)
# Out:
# 12

# %%
abs(-12, 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-ebc13159f5c8> in <module>()
# ----> 1 abs(-12, 4)
#
# TypeError: abs() takes exactly one argument (2 given)

# %%
abs?

# %%
abs(5 - 1.3)
# Out:
# 3.7

# %%
round(abs(5-1.3))
# Out:
# 4

# %%
#what will it print?

max(2, 2 + 3, 4, max(56, -6))
# Out:
# 56

# %%
from IPython.display import Image
Image("anatomy.png")

# %%
import math
math.sqrt(9)
# Out:
# 3.0

# %%
9 ** 0.5
# Out:
# 3.0

# %%
(3 ** 2 + 4 ** 2) ** 0.5
# Out:
# 5.0

# %%
math.sqrt(3 ** 2 + 4 ** 2)
# Out:
# 5.0

# %%
math.sin(math.pi / 2)
# Out:
# 1.0

# %%
math.log(9, 9)
# Out:
# 1.0

# %%
math.pow?

# %%
from IPython.display import Image
Image("q2.png")

# %%
x=3
y=-2

# %%
abs(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-ff717ca3eb6e> in <module>()
# ----> 1 abs(x, y)
#
# TypeError: abs() takes exactly one argument (2 given)

# %%
math.pow(x, abs(y))
# Out:
# 9.0

# %%
round(x, max(abs(y**2))))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-198576d4e389> in <module>()
# ----> 1 round(x, max(abs(y**2)))
#
# TypeError: 'int' object is not iterable

# %%
math.pow(x, math.pow(y, x))
# Out:
# 0.00015241579027587258
